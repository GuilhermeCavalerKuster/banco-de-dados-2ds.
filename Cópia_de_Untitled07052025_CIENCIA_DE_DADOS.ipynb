# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeCavalerKuster/banco-de-dados-2ds./blob/main/C%C3%B3pia_de_Untitled07052025_CIENCIA_DE_DADOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > # <b>PROJETO: Introdução à Data Science</b>
# > CURSO: Técnico em Desenvolvimento de Sistemas
# > DISCIPLINA: Ciência de Dados
# > PROFESSORA: Carla Silveira
# > ESTUDANTE: escreva o seu nome!
# > TURMA: 3DS       |    DATA: 07/05/2025

# %% [markdown]
# >IMPORTANTE!
# >Execute as instruções SEQUENCIALMENTE, sem mudar a ordem, para completar este notebook com análise e visualização de dados usando a biblioteca Pandas do Python e as bases de dados GroupLens (MovieLens) e TMDb (The Movie Database).
# </br> >> Use o botão de ícone Play para executar o código de uma célula após a outra, porque cada célula depende das anteriores.

# %% [markdown]
# > <b>1. Renomeie este notebook como `Introducao-a-Data-Science.ipynb` e salve uma cópia no seu Drive.</b>

# %% [markdown]
# > <b>2. Upload dos dados: clique no ícone de pasta no lado esquerdo e na folha com seta, selecione o arquivo `ratings.csv` na pasta "aula0". Será exibida mensagem sobre exclusão dos arquivos ao encerrar o ambiente de execução, clique em OK e aguarde concluir o upload.</b>

# %% [markdown]
# > <b>3. São muitas informações, portanto atribuiremos tudo isso a <b>`notas`</b> e, em vez de todas, pediremos para que apenas as cinco primeiras avaliações sejam exibidas, isto é, a "cabeça" (head) da lista de elementos:
# >
# > <i>*Procure o código embaixo desta parte ⬆ da [transcrição](https://cursos.alura.com.br/course/data-science-primeiros-passos/task/49676), copie depois do comentário na célula seguinte ⬇ e clique em ▶:</i></b>

# %%
# Importa biblioteca Pandas, carrega e visualiza 5 linhas iniciais da base de dados
import pandas as pd

pd.read_csv("ratings.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_563/545185918.py in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 pd.read_csv("ratings.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# > <b>4. Para visualizar quantas avaliações existem na base de dados, digite a linha de código: `notas.shape` depois do comentário na célula seguinte ⬇:</b>

# %%
# Quantas avaliações e colunas há na base de dados?
import pandas as pd

notas = pd.read_csv("ratings.csv")
notas.head()

# %% [markdown]
# Obs.: O contador à esquerda, na tabela, é denominado <b>índice</b> e não se  considera como coluna.

# %% [markdown]
# > <b>5. Continuando, caso queiramos trabalhar com o português, e não inglês, alteraremos os nomes das nossas colunas com o atributo `columns`:
# >
# > <i>*Procure o código embaixo desta parte ⬆ da [transcrição](https://cursos.alura.com.br/course/data-science-primeiros-passos/task/49676), copie depois do comentário na célula seguinte ⬇ e clique em ▶:</i></b>

# %%
# Renomeia colunas em português
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]

# %% [markdown]
# Obs.: Os nomes das <b>colunas em inglês</b> são, respectivamente: <i>userId,	movieId,	rating, timestamp</i>.

# %% [markdown]
# > <b>6. Para visualizar a alteração na base de dados, digite a linha de comando: `notas.head()`depois do comentário na célula seguinte ⬇: </b>

# %%
# Confere alterações no DataFrame - 5 linhas iniciais
notas['nota']

# %% [markdown]
# Obs.: <b>notas</b> é um objeto do Pandas com várias colunas e 0 ou várias linhas, com uma estrutura de dados tabular (ou tabela) conhecida como <b>Pandas DataFrame</b>.

# %% [markdown]
# > <b>7. A coluna "nota" contém os valores 4.0 e 5.0, mas será que eles são únicos? Para consultarmos todos os valores desta coluna, digitaremos e rodaremos o seguinte código:
# >
# > <i>*Procure o código embaixo desta parte ⬆ da [transcrição](https://cursos.alura.com.br/course/data-science-primeiros-passos/task/49676), copie depois do comentário na célula seguinte ⬇ e clique em ▶:</i></b>

# %%
# Exibe todas a linhas da coluna "nota"
notas['nota'].value_counts()

# %% [markdown]
# Obs.: Na solicitação de única coluna, por padrão, a saída da execução é uma série de números, chamada de <b>Pandas Series</b>, pois representa uma série de dados.

# %% [markdown]
#  > <b>8. Para saber quais são os valores colocados na coluna "nota" de maneira única, digite a linha de comando: `notas['nota'].unique()`depois do comentário na célula seguinte ⬇:</b>

# %%
# Exibe valores únicos da coluna
notas['nota'].mean()

# %% [markdown]
# > <b>9. Se quisermos saber quantas vezes uma nota específica aparece nesta coluna, poderemos usar:
# >
# > <i>*Procure o código embaixo desta parte ⬆ da [transcrição](https://cursos.alura.com.br/course/data-science-primeiros-passos/task/49676), copie depois do comentário na célula seguinte ⬇ e clique em ▶:</i></b>

# %%
# Contagem das notas na coluna "nota"

# %% [markdown]
# Obs.: São impressas 2 colunas de valores, a 1ª com notas e a 2ª com a quantidade de vezes que foi usada, em ordem decrescente.

# %% [markdown]
# > <b>10. Para encontrarmos a média destas notas, utilizaremos:
# >
# > <i>*Procure o código embaixo desta parte ⬆ da [transcrição](https://cursos.alura.com.br/course/data-science-primeiros-passos/task/49676), copie depois do comentário na célula seguinte ⬇ e clique em ▶:</i></b>

# %%
# Calcula e exibe a média das notas

# %% [markdown]
# > <b>11. A impressão visual de um conjunto de dados é chamada "plotar" (plot), e o Pandas possui um método plot() que faz isso. Para plotar a série de dados, digite a linha de comando `notas.nota.plot()`depois do comentário na célula seguinte ⬇:</b>

# %%
# Imprime a série de dados

# %% [markdown]
# Obs.: A visualização do gráfico está confusa, pois <b>o eixo X mostra os índices da tabela</b>, que vão de 0 a 100.000. O método `plot()`do Pandas usa índices automaticamente, ligando pontos por retas. Para melhorar, é preciso definir manualmente o eixo X com valores mais relevantes.

# %% [markdown]
# > <b>12. Na verdade, queremos saber quantas vezes cada informação aparece nesse conjunto de dados, o que pode ser visualizado em um histograma. Para gerá-lo, usaremos, no método `plot()`, o argumento `kind`com o valor `hist`:
# >
# > <i>*Procure o código embaixo desta parte ⬆ da [transcrição](https://cursos.alura.com.br/course/data-science-primeiros-passos/task/49677), copie depois do comentário na célula seguinte ⬇ e clique em ▶:</i></b>

# %%
# Gera um histograma para visualizar a distribuição das notas

# %% [markdown]
# Obs.: Na análise do histograma, percebe-se que a nota 5 apareceu diversas vezes; a nota 4,5 nem tantas; <b>a nota 4 é a que mais apareceu e isso confirma a contagem feita antes no item 9 deste notebook</b>.

# %% [markdown]
# ><b>13. Vamos supor agora que metade das notas do nosso conjunto são maiores que 3, e a outra metade são menores. Mas e se quiséssemos saber exatamente qual é o valor que divide nossos dados na metade? Esse valor é a mediana (<i>"median"</i>). Para efeito de comparação, vamos imprimir tanto a média quanto a mediana na tela.
# >
# > <i>*Procure o código embaixo desta parte ⬆ da [transcrição](https://cursos.alura.com.br/course/data-science-primeiros-passos/task/49677), copie depois do comentário na célula seguinte ⬇ e clique em ▶:</i></b>

# %%
# Mostra a média e a mediana das notas

# %% [markdown]
# ><b>14. Nesse caso, a mediana foi muito próxima da média, mas isso não é uma garantia. É possível, ainda, tirar essas e outras medidas de uma só vez, pedindo o `describe() dessa série (ou de um <i>dataframe):
# <i>*Procure o código embaixo desta parte ⬆ da transcrição, copie depois do comentário na célula seguinte ⬇ e clique em ▶:</i></b>

# %%
# Descreve estatísticas resumidas da série de dados (contagem, média, desvio padrão, mínimo, quartis, máximo)

# %% [markdown]
# ><b>15. Em um código para gerar um gráfico <i>boxplot</i>, deve-se importar a biblioteca com `import seaborn as sns` (importação padrão); chamar a função `sns.boxplot()`; passar `notas.nota`como parâmetro.
# Para gerar esse tipo de gráfico, escreva a linha de comando adequada a cada comentário da célula seguinte ⬇:</b>

# %%
# Importa a biblioteca Seaborn


# Importa o Matplotlib para exibir o gráfico


# Gera o boxplot da coluna "nota"


# Exibe o gráfico

# %% [markdown]
# ### Parabéns por chegar ao final deste notebook! 🎆
# ### Clique em Arquivo/Salvar e fixar revisão.
